# %%
import requests
from xml.etree import ElementTree as ET
import pandas as pd
import folium

# 미술관 API 요청 URL
art_gallery_url = 'http://www.culture.go.kr/openapi/rest/cultureartspaces/artgallery'

# 박물관 API 요청 URL
museum_url = 'http://www.culture.go.kr/openapi/rest/cultureartspaces/museum'

# 공연장 API 요청 URL
perform_url = 'http://www.culture.go.kr/openapi/rest/cultureartspaces/performingplace'

# 필요한 파라미터 설정 (예시)
params = {
    'ServiceKey': 'MY_API_KEY',
    'areaCode': 1,
}

# 구글 지도 Street View API 요청 URL
street_view_api_url = 'https://maps.googleapis.com/maps/api/streetview'

# 구글 지도 Street View API 키
api_key = 'MY_API_KEY'

# 미술관 정보 가져오기
response_gallery = requests.get(art_gallery_url, params=params)

if response_gallery.status_code == 200:
    root_gallery = ET.fromstring(response_gallery.content)

    data_list_gallery = []

    for item in root_gallery.findall('msgBody/placeList'):
        data_dict = {}
        try:
            data_dict['name'] = item.find('culName').text  # 이름 추출

        except AttributeError:
            print(f"Failed to find 'culName' in item: {ET.tostring(item)}")
            data_dict['name'] = None

        try:
            data_dict['latitude'] = float(item.find('gpsY').text)  # 위도 추출 ('gpsY')
            data_dict['longitude'] = float(item.find('gpsX').text)  # 경도 추출 ('gpsX')
        except (AttributeError, ValueError):
            print(f"Failed to find or convert latitude/longitude in item: {ET.tostring(item)}")
            continue

        data_list_gallery.append(data_dict)

    df_gallery = pd.DataFrame(data_list_gallery)

else:
    print(f'Request failed with status code {response.status_code}')

# 박물관 정보 가져오기
response_museum= requests.get(museum_url, params=params)

if response_museum.status_code == 200:
    root_museum= ET.fromstring(response_museum.content)

    data_list_museum= []

    for item in root_museum.findall('msgBody/placeList'):
        data_dict= {}
        try:
            data_dict['name']= item.find('culName').text

        except AttributeError:
            print(f"Failed to find 'culName' in item: {ET.tostring(item)}")
            data_dict['name']= None

        try:
          data_dict['latitude']= float(item.find('gpsY').text)
          data_dict['longitude']= float(item.find('gpsX').text)

        except (AttributeError, ValueError):
            print(f"Failed to find or convert latitude/longitude in item: {ET.tostring(item)}")
            continue

        data_list_museum.append(data_dict)

    df_museum= pd.DataFrame(data_list_museum)

else:
  	print(f'Request failed with status code {response.status_code}')


# 공연장 정보 가져오기
response_perform= requests.get(perform_url, params=params)

if response_perform.status_code == 200:
    root_perform= ET.fromstring(response_perform.content)

    data_list_perform= []

    for item in root_perform.findall('msgBody/placeList'):
        data_dict= {}
        try:
            data_dict['name']= item.find('culName').text

        except AttributeError:
            print(f"Failed to find 'culName' in item: {ET.tostring(item)}")
            data_dict['name']= None

        try:
          data_dict['latitude']= float(item.find('gpsY').text)
          data_dict['longitude']= float(item.find('gpsX').text)

        except (AttributeError, ValueError):
            print(f"Failed to find or convert latitude/longitude in item: {ET.tostring(item)}")
            continue

        data_list_perform.append(data_dict)

    df_perform= pd.DataFrame(data_list_perform)

else:
  	print(f'Request failed with status code {response.status_code}')



map_seoul= folium.Map(location=[37.56,126.97], zoom_start=12)

for idx in df_gallery.index:
  	if pd.notna(df_gallery.loc[idx,'name']) and pd.notna(df_gallery.loc[idx,'latitude']) and pd.notna(df_gallery.loc[idx,'longitude']):
    	  folium.Marker(
            location=[df_gallery.loc[idx,'latitude'], df_gallery.loc[idx,'longitude']],
            popup=df_gallery.loc[idx,'name'],
            icon=folium.Icon(icon='cloud')
        ).add_to(map_seoul)


for idx in df_museum.index:
  	if pd.notna(df_museum.loc[idx,'name']) and pd.notna(df_museum.loc[idx,'latitude']) and pd.notna(df_museum.loc[idx,'longitude']):
    	  folium.Marker(
            location=[df_museum.loc[idx,'latitude'], df_museum.loc[idx,'longitude']],
            popup=df_museum.loc[idx,'name'],
            icon=folium.Icon(color='red', icon='cloud')
       ).add_to(map_seoul)

for idx in df_perform.index:
  	if pd.notna(df_perform.loc[idx,'name']) and pd.notna(df_perform.loc[idx,'latitude']) and pd.notna(df_perform.loc[idx,'longitude']):
    	  folium.Marker(
            location=[df_perform.loc[idx,'latitude'], df_perform.loc[idx,'longitude']],
            popup=df_perform.loc[idx,'name'],
            icon=folium.Icon(color='green', icon='cloud')
       ).add_to(map_seoul)


map_seoul.save('seoul_art_and_museums.html')

map_seoul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f040c3244f844f518775f091ab7cd97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f040c3244f844f518775f091ab7cd97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f040c3244f844f518775f091ab7cd97 = L.map(
#                 &quot;map_8f040c3244f844f518775f091ab7cd97&quot;,
#                 {
#                     center: [37.56, 126.97],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9af212735a0b504d2d42ec2f2f94777c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8f040c3244f844f518775f091ab7cd97);
#
#
#             var marker_7dcd12129f25883af3b16426d7793012 = L.marker(
#                 [37.519746957180544, 127.02147006525325],
#                 {}
#             ).addTo(map_8f040c3244f844f518775f091ab7cd97);
#
#
#             var icon_5d13fa951fe7b74b89ea6140343a58bc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7dcd12129f25883af3b16426d7793012.setIcon(icon_5d13fa951fe7b74b89ea6140343a58bc);
#
#
#         var popup_80ca8cdfa3205343ef8cc7ef6de7a0ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_16e20e16070348f0aa4dc5d660941ec5 = $(`&lt;div id=&quot;html_16e20e16070348f0aa4dc5d660941ec5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2GIL29 GALLERY&lt;/div&gt;`)[0];
#                 popup_80ca8cdfa3205343ef8cc7ef6de7a0ab.setContent(html_16e20e16070348f0aa4dc5d660941ec5);
#
#
#
#         marker_7dcd12129f25883af3b16426d7793012.bindPopup(popup_80ca8cdfa3205343ef8cc7ef6de7a0ab)
#         ;
#
#
#
#
#             var marker_d993550b3cfff01a7059a1e6cd888d9b = L.marker(
#                 [37.5692641279951, 126.92838199580476],
#                 {}
#             ).addTo(map_8f040c3244f844f518775f091ab7cd97);
#
#
#             var icon_7d4a90540d5bdc1a2563447f097f7222 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d993550b3cfff01a7059a1e6cd888d9b.setIcon(icon_7d4a90540d5bdc1a2563447f097f7222);
#
#
#         var popup_fb06e8626321056da1b9fc4dff93e78d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5619692d92e89c9233297d8450dca57d = $(`&lt;div id=&quot;html_5619692d92e89c9233297d8450dca57d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ARTION(아티온)&lt;/div&gt;`)[0];
#                 popup_fb06e8626321056da1b9fc4dff93e78d.setContent(html_5619692d92e89c9233297d8450dca57d);
#
#
#
#         marker_d993550b3cfff01a7059a1e6cd888d9b.bindPopup(popup_fb06e8626321056da1b9fc4dff93e78d)
#         ;
#
#
#
#
#             var marker_9b74fcd1ff7b7333a2bbd0239b6662e3 = L.marker(
#                 [37.52346981046802, 127.0467432642712],
#                 {}
#             ).addTo(map_8f040c3244f844f518775f091ab7cd97);
#
#
#             var icon_c579b3e5fb9978bfb2033c81d55d4080 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b74fcd1ff7b7333a2bbd0239b6662e3.setIcon(icon_c579b3e5fb9978bfb2033c81d55d4080);
#
#
#         var popup_fabaacae61347722b77f48a063ad13eb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ceb424c4cb686fe5bd745f78e0332a7e = $(`&lt;div id=&quot;html_ceb424c4cb686fe5bd745f78e0332a7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;AZULEJO GALLERY (아줄레주 갤러리)&lt;/div&gt;`)[0];
#                 popup_fabaacae61347722b77f48a063ad13eb.setContent(html_ceb424c4cb686fe5bd745f78e0332a7e);
#
#
#
#         marker_9b74fcd1ff7b7333a2bbd0239b6662e3.bindPopup(popup_fabaacae61347722b77f48a063ad13eb)
#         ;
#
#
#
#
#             var marker_c27371733536c2796b577db811ceeb86 = L.marker(
#                 [37.39496118209332, 127.7378051005832],
#                 {}
#             ).addTo(map_8f040c3244f844f518775f091ab7cd97);
#
#
#             var icon_be7f88ae94b08e350e6b8c79b5b9d816 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses

# %%
import requests
from xml.etree import ElementTree as ET
import pandas as pd
import folium

# 미술관 API 요청 URL
art_gallery_url = 'http://www.culture.go.kr/openapi/rest/cultureartspaces/artgallery'

# 박물관 API 요청 URL
museum_url = 'http://www.culture.go.kr/openapi/rest/cultureartspaces/museum'

# 공연장 API 요청 URL
perform_url = 'http://www.culture.go.kr/openapi/rest/cultureartspaces/performingplace'

# 필요한 파라미터 설정 (예시)
params = {
    'ServiceKey': 'J7eSd1v9CxPBqa+NuhF9JKvRQX2EHh9t6wtILRwPAk4hl/BvkK0gDocAeIFZ/yiMmMIFgN7vHDLR58rIdKh4bA==',  # 실제 서비스 키로 변경해야 합니다.
    'areaCode': 1,
}

# 구글 지도 Street View API 요청 URL
street_view_api_url = 'https://maps.googleapis.com/maps/api/streetview'

# 구글 지도 Street View API 키
api_key = 'AIzaSyAm7vcUGnEM97S1r0fYUwxsxgukZJzxJPo'

# 미술관 정보 가져오기
response_gallery = requests.get(art_gallery_url, params=params)

if response_gallery.status_code == 200:
    root_gallery = ET.fromstring(response_gallery.content)

    data_list_gallery = []

    for item in root_gallery.findall('msgBody/placeList'):
        data_dict = {}
        try:
            data_dict['name'] = item.find('culName').text  # 이름 추출

        except AttributeError:
            print(f"Failed to find 'culName' in item: {ET.tostring(item)}")
            data_dict['name'] = None

        try:
            data_dict['latitude'] = float(item.find('gpsY').text)  # 위도 추출 ('gpsY')
            data_dict['longitude'] = float(item.find('gpsX').text)  # 경도 추출 ('gpsX')
        except (AttributeError, ValueError):
            print(f"Failed to find or convert latitude/longitude in item: {ET.tostring(item)}")
            continue

        data_list_gallery.append(data_dict)

    df_gallery = pd.DataFrame(data_list_gallery)

else:
    print(f'Request failed with status code {response.status_code}')

# 박물관 정보 가져오기
response_museum= requests.get(museum_url, params=params)

if response_museum.status_code == 200:
    root_museum= ET.fromstring(response_museum.content)

    data_list_museum= []

    for item in root_museum.findall('msgBody/placeList'):
        data_dict= {}
        try:
            data_dict['name']= item.find('culName').text

        except AttributeError:
            print(f"Failed to find 'culName' in item: {ET.tostring(item)}")
            data_dict['name']= None

        try:
          data_dict['latitude']= float(item.find('gpsY').text)
          data_dict['longitude']= float(item.find('gpsX').text)

        except (AttributeError, ValueError):
            print(f"Failed to find or convert latitude/longitude in item: {ET.tostring(item)}")
            continue

        data_list_museum.append(data_dict)

    df_museum= pd.DataFrame(data_list_museum)

else:
  	print(f'Request failed with status code {response.status_code}')


# 공연장 정보 가져오기
response_perform= requests.get(perform_url, params=params)

if response_perform.status_code == 200:
    root_perform= ET.fromstring(response_perform.content)

    data_list_perform= []

    for item in root_perform.findall('msgBody/placeList'):
        data_dict= {}
        try:
            data_dict['name']= item.find('culName').text

        except AttributeError:
            print(f"Failed to find 'culName' in item: {ET.tostring(item)}")
            data_dict['name']= None

        try:
          data_dict['latitude']= float(item.find('gpsY').text)
          data_dict['longitude']= float(item.find('gpsX').text)

        except (AttributeError, ValueError):
            print(f"Failed to find or convert latitude/longitude in item: {ET.tostring(item)}")
            continue

        data_list_perform.append(data_dict)

    df_perform= pd.DataFrame(data_list_perform)

else:
  	print(f'Request failed with status code {response.status_code}')



map_seoul= folium.Map(location=[37.56,126.97], zoom_start=12)

def add_marker_with_image(row, color):
    if pd.notna(row['name']) and pd.notna(row['latitude']) and pd.notna(row['longitude']):
        url = f"{street_view_api_url}?location={row['latitude']},{row['longitude']}&size=200x200&key={api_key}"
        image_html = f'<img src="{url}">'
        popup_content = f'{image_html}<br>{row["name"]}'
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=popup_content,
            icon=folium.Icon(color=color, icon='cloud')
        ).add_to(map_seoul)


for idx, row in df_gallery.iterrows():
    add_marker_with_image(row, 'blue')

for idx, row in df_museum.iterrows():
    add_marker_with_image(row, 'red')

for idx, row in df_perform.iterrows():
    add_marker_with_image(row, 'green')

map_seoul
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b4b0fac4da491f7fe37fac7d532d10a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b4b0fac4da491f7fe37fac7d532d10a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b4b0fac4da491f7fe37fac7d532d10a = L.map(
#                 &quot;map_1b4b0fac4da491f7fe37fac7d532d10a&quot;,
#                 {
#                     center: [37.56, 126.97],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_247cd8ccc2e342b45e45b10374926906 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1b4b0fac4da491f7fe37fac7d532d10a);
#
#
#             var marker_fe6d6b2af93640ae9932b53a46cb2302 = L.marker(
#                 [37.519746957180544, 127.02147006525325],
#                 {}
#             ).addTo(map_1b4b0fac4da491f7fe37fac7d532d10a);
#
#
#             var icon_bfc5e46db29ec4247644788aaac21ac5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_fe6d6b2af93640ae9932b53a46cb2302.setIcon(icon_bfc5e46db29ec4247644788aaac21ac5);
#
#
#         var popup_0aaa6855fcaba4ff674c4ddbcacf1a02 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b788b64bab3c4d65db9adb3029c53c6c = $(`&lt;div id=&quot;html_b788b64bab3c4d65db9adb3029c53c6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;https://maps.googleapis.com/maps/api/streetview?location=37.519746957180544,127.02147006525325&amp;size=200x200&amp;key=AIzaSyAm7vcUGnEM97S1r0fYUwxsxgukZJzxJPo&quot;&gt;&lt;br&gt;2GIL29 GALLERY&lt;/div&gt;`)[0];
#                 popup_0aaa6855fcaba4ff674c4ddbcacf1a02.setContent(html_b788b64bab3c4d65db9adb3029c53c6c);
#
#
#
#         marker_fe6d6b2af93640ae9932b53a46cb2302.bindPopup(popup_0aaa6855fcaba4ff674c4ddbcacf1a02)
#         ;
#
#
#
#
#             var marker_dff06b683ce7e00e7a1eb68fa9e437e5 = L.marker(
#                 [37.5692641279951, 126.92838199580476],
#                 {}
#             ).addTo(map_1b4b0fac4da491f7fe37fac7d532d10a);
#
#
#             var icon_898ed45cea62985c3de53d33958adae0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dff06b683ce7e00e7a1eb68fa9e437e5.setIcon(icon_898ed45cea62985c3de53d33958adae0);
#
#
#         var popup_2c39c7df1e078b693ced8dbc229eeb6b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6b05be3091ba5cf967641951826ddbe6 = $(`&lt;div id=&quot;html_6b05be3091ba5cf967641951826ddbe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;https://maps.googleapis.com/maps/api/streetview?location=37.5692641279951,126.92838199580476&amp;size=200x200&amp;key=AIzaSyAm7vcUGnEM97S1r0fYUwxsxgukZJzxJPo&quot;&gt;&lt;br&gt;ARTION(아티온)&lt;/div&gt;`)[0];
#                 popup_2c39c7df1e078b693ced8dbc229eeb6b.setContent(html_6b05be3091ba5cf967641951826ddbe6);
#
#
#
#         marker_dff06b683ce7e00e7a1eb68fa9e437e5.bindPopup(popup_2c39c7df1e078b693ced8dbc229eeb6b)
#         ;
#
#
#
#
#             var marker_e4a34fbf513cef580c11a475d698f20b = L.marker(
#                 [37.52346981046802, 127.0467432642712],
#                 {}
#             ).addTo(map_1b4b0fac4da491f7fe37fac7d532d10a);
#
#
#             var icon_cd563dabefcee868d42ad5b480ff2514 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;cloud&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e4a34fbf513cef580c11a475d698f20b.setIcon(icon_cd563dabefcee868d42ad5b480ff2514);
#
#
#         var popup_3ade17a2d16b957668dcfc778e8f64d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb4ccd0bc444df014f19342f6d97506b = $(`&lt;div id=&quot;html_eb4ccd0bc444df014f19342f6d97506b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;img src=&quot;https://maps.googleapis.com/maps/api/streetview?location=37.52346981046802,127.0467432642712&amp;size=200x200&amp;key=AIzaSyAm7vcUGnEM97S1r0fYUwxsxgukZJzxJPo&quot;&gt;&lt;br&gt;AZULEJO GALLERY (아줄레주 갤러리)&lt;/div&gt;`)[0];
